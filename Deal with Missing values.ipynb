# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %% [markdown]
# ## deleting the column wiht missing data

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ##deleting the column wiht missing data

# %%
df2 = df.copy()

# %%
df2.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2.dropna(inplace = True)

# %%
df2.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df2.shape
# Out:
# (38832, 15)

# %% [markdown]
# ## Filling missing values - Imputation
# i) Numerical mean - use mean

# %%
df3 = df.copy()

# %%
df3.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
mean_value = df3['reviews_per_month'].mean()
df3['reviews_per_month'].fillna(mean_value, inplace = True)
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_7508\4010994561.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['reviews_per_month'].fillna(mean_value, inplace = True)

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  19-10-2018
# 1  Entire home/apt    225               1                 45  21-05-2019
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  05-07-2019
# 4  Entire home/apt     80              10                  9  19-11-2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0           0.210000                               6               365
# 1           0.380000                               2               355
# 2           1.373151                               1               365
# 3           4.640000                               1               194
# 4           0.100000                               1                 0

# %%
df3.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Filling categorical data

# %%
df3.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   938
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df3['last_review'].fillna(df3['last_review'].value_counts().index[0],inplace = True)
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_7508\343355254.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['last_review'].fillna(df3['last_review'].value_counts().index[0],inplace = True)

# %%
df3.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
df4 = df.copy()

# %%
df4.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df4['last_review'].fillna('Not Reviewed',inplace = True)

# %%
df4.sample(10)
# Out:
#              id                                              name    host_id  \
# 45634  34867398            Sunset Park Rustic Bed Room for 2 W/AC   38119047
# 27878  21829821   Spacious room apt. Manhattan near Times Square.  159150155
# 20747  16440192              Interfaith Retreats (Mother Theresa)   16677326
# 43031  33406037             Aloft Manhattan Downtown-7 Nights Min    5144567
# 24938  19981671                                    DaDukes Dreams  139879568
# 9671    7434316               Parkside Brooklyn Artist Apartment!    3861404
# 12856   9797293                          East Harlem Holiday Stay    5474579
# 7189    5252343               Close to LGA/JFK & 15min to Midtown     419629
# 23129  18729985  Bright  and cozy room 20 min away from Manhattan    8076786
# 833      294280                  Loft Suite @ The Box House Hotel     417504
#
#                  host_name neighbourhood_group              neighbourhood  \
# 45634                   Wu            Brooklyn                Sunset Park
# 27878                Ronak           Manhattan             Hell's Kitchen
# 20747       Alex And Zeena           Manhattan                    Chelsea
# 43031                  Yun           Manhattan         Financial District
# 24938              Alberto              Queens           Long Island City
# 9671              Stefanie            Brooklyn  Prospect-Lefferts Gardens
# 12856                 Seun           Manhattan                East Harlem
# 7189                 Nicky              Queens                   Elmhurst
# 23129                 Suri            Brooklyn                Sunset Park
# 833    The Box House Hotel            Brooklyn                 Greenpoint
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 45634  40.64613  -74.00736     Private room     40               1
# 27878  40.76793  -73.98583     Private room    150               1
# 20747  40.74837  -73.99639     Private room     85               1
# 43031  40.71086  -74.00746     Private room    169               7
# 24938  40.76626  -73.94058     Private room     84               1
# 9671   40.65628  -73.96014     Private room     70               5
# 12856  40.79617  -73.93452  Entire home/apt     85               1
# 7189   40.74125  -73.89035     Private room     47               2
# 23129  40.65890  -74.00018     Private room    150               2
# 833    40.73857  -73.95435  Entire home/apt    199               3
#
#        number_of_reviews   last_review  reviews_per_month  \
# 45634                  8    08-07-2019               5.45
# 27878                  1    21-11-2017               0.05
# 20747                 70    24-06-2019               2.27
# 43031                  2    24-05-2019               0.95
# 24938                 70    29-05-2019               3.12
# 9671                   3    22-09-2015               0.06
# 12856                  0  Not Reviewed                NaN
# 7189                   2    23-02-2015               0.04
# 23129                  6    23-03-2019               0.27
# 833                   23    23-04-2019               0.26
#
#        calculated_host_listings_count  availability_365
# 45634                               2                89
# 27878                               1                 0
# 20747                              12               344
# 43031                              13               358
# 24938                               6               321
# 9671                                2                 0
# 12856                               1                 0
# 7189                                1                17
# 23129                               3               365
# 833                                28                81

# %% [markdown]
# ## Advanced Imputation

# %%
df6 = df.copy()

# %%
df6.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df6['reviews_per_month'].interpolate(inplace =True)
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_7508\3508294319.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df6['reviews_per_month'].interpolate(inplace =True)

# %%
df6
# Out:
#          id                                              name  host_id  \
# 0      2539                Clean & quiet apt home by the park     2787
# 1      2595                             Skylit Midtown Castle     2845
# 2      3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3      3831                   Cozy Entire Floor of Brownstone     4869
# 4      5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ...     ...                                               ...      ...
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group    neighbourhood  latitude  \
# 0               John            Brooklyn       Kensington  40.64749
# 1           Jennifer           Manhattan          Midtown  40.75362
# 2          Elisabeth           Manhattan           Harlem  40.80902
# 3        LisaRoxanne            Brooklyn     Clinton Hill  40.68514
# 4              Laura           Manhattan      East Harlem  40.79851
# ...              ...                 ...              ...       ...
# 48901           Kate           Manhattan   Hell's Kitchen  40.76076
# 48902         Laurie            Brooklyn      South Slope  40.66829
# 48903        Claudio           Manhattan  Upper West Side  40.79826
# 48904          Alina           Manhattan     West Village  40.73530
# 48905  Allen & Irina            Brooklyn     Williamsburg  40.70837
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48901  -73.98867     Private room     85               2                188
# 48902  -73.98779     Private room     89               4                167
# 48903  -73.96113     Private room     85               2                113
# 48904  -74.00525  Entire home/apt    120              90                 27
# 48905  -73.95352  Entire home/apt    140               2                148
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      19-10-2018               0.21                               6
# 1      21-05-2019               0.38                               2
# 2             NaN               2.51                               1
# 3      05-07-2019               4.64                               1
# 4      19-11-2018               0.10                               1
# ...           ...                ...                             ...
# 48901  23-06-2019               1.50                               1
# 48902  24-06-2019               1.34                               3
# 48903  05-07-2019               0.91                               1
# 48904  31-10-2018               0.22                               1
# 48905  29-06-2019               1.20                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48901                39
# 48902               314
# 48903               333
# 48904                 0
# 48905                46
#
# [48906 rows x 16 columns]

# %%
df6.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df7 = df.copy()

# %%
df7.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df7.drop('reviews_per_month', axis = 1, inplace = True)

# %%
df7.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64
